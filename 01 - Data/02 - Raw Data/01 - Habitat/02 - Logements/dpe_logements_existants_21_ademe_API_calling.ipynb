# %% [markdown]
# ## Import of data related to new housing (post 2021), with DPE (Energetic Performance Diagnosis) and GES (Greenhouse Gas) scores.

# %% [markdown]
# ### Libs imports

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv

# %%
# Loading environment variables
load_dotenv()
API_KEY = os.getenv('ADEME_API_KEY')

# %% [markdown]
# ### Connecting to ADEME's API (and testing the response's status code)

# %%
url=  'https://data.ademe.fr/data-fair/api/v1/datasets/dpe03existant/lines' # database url
headers = {
        'accept': 'application/json',
        'x-apikey': API_KEY
        }
params = {
        'select': '_geopoint,adresse_ban,annee_construction,numero_dpe,etiquette_dpe,etiquette_ges,conso_5_usages_par_m2_ef,emission_ges_5_usages_par_m2,categorie_enr',
        'qs': 'code_departement_ban:75'
        }
response = requests.get(url, headers=headers, params=params)
response.status_code
# Out:
# 200

# %% [markdown]
# ### Checking data we have connected to

# %%
pd.DataFrame(response.json()["results"])
# Out:
#                              categorie_enr  \
# 0   réseau de chaleur ou de froid vertueux
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4   réseau de chaleur ou de froid vertueux
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                         pompe à chaleur
# 11                                     NaN
#
#                                           adresse_ban  \
# 0                        50 Rue du Disque 75013 Paris
# 1                        74 Rue de Sèvres 75007 Paris
# 2                     7 Rue Pierre Sémard 75009 Paris
# 3                  19 Rue Antoine Chantin 75014 Paris
# 4   12 Avenue de la Porte de Clignancourt 75018 Paris
# 5                  101 Rue du Chemin Vert 75011 Paris
# 6           29 Avenue de la Motte-Picquet 75007 Paris
# 7                    70b Avenue de Clichy 75017 Paris
# 8                          27 Rue Marbeuf 75008 Paris
# 9                       9b Rue de Valence 75005 Paris
# 10          53t Quai des Grands Augustins 75006 Paris
# 11                 198 Boulevard Voltaire 75011 Paris
#
#     conso_5_usages_par_m2_ef etiquette_ges  annee_construction  \
# 0                      238.0             D              1948.0
# 1                      206.7             D              1948.0
# 2                      125.8             B              1930.0
# 3                       93.0             B              1987.0
# 4                      104.0             C                 NaN
# 5                       90.0             A              1947.0
# 6                      167.0             D              1947.0
# 7                      288.0             D              1948.0
# 8                      203.0             D                 NaN
# 9                      190.0             C              1947.0
# 10                     137.0             C                 NaN
# 11                     554.6             F              1930.0
#
#                                _geopoint  emission_ges_5_usages_par_m2  \
# 0    48.82458102161721,2.363825947937033                          36.0
# 1    48.84762702994544,2.318554043655058                          45.7
# 2   48.877989001472606,2.347287007868445                           8.0
# 3    48.82729698043097,2.321912996369212                           6.0
# 4   48.89892902627486,2.3444450656734404                          15.0
# 5      48.861080983623,2.380873994245739                           6.0
# 6     48.8551579728205,2.307180967430216                          37.0
# 7   48.887955965292726,2.325008019561719                          53.0
# 8   48.869091982871474,2.304235983873164                          37.0
# 9   48.83768798913495,2.3495429633026275                          28.0
# 10  48.85554999608954,2.3409810483800597                          28.0
# 11   48.85390415880148,2.386332773497231                         111.4
#
#        numero_dpe etiquette_dpe _score
# 0   2275E0252200Y             D   None
# 1   2275E1242094U             D   None
# 2   2275E0392026W             D   None
# 3   2275E0464107F             D   None
# 4   2275E1334975D             C   None
# 5   2275E0647807P             C   None
# 6   2275E0479391B             D   None
# 7   2275E0348574Q             E   None
# 8   2275E1153202W             E   None
# 9   2275E0725539H             E   None
# 10  2275E1201596E             C   None
# 11  2175E1028836N             G   None

# %% [markdown]
# ### Main function importing all data from ADEME's database
# #### (segmenting API calls according to districts, construction periods and diagnostician's time of visit, to avoid reaching the 10000 entries' limit of the ADEME's API)

# %%
def get_all_dpe_data():
    # Initialize empty DataFrame with desired columns
    columns = ['_geopoint', 'adresse_ban', 'annee_construction', 'numero_dpe', 'etiquette_dpe', 'etiquette_ges', 
              'conso_5_usages_par_m2_ef', 'emission_ges_5_usages_par_m2', 'categorie_enr', 'date_visite_diagnostiqueur']
    final_df = pd.DataFrame(columns=columns)
    
    # Postal codes of the 20 Parisian districts
    postal_codes = [f'750{str(i).zfill(2)}' for i in range(1, 21)]
    
    # Building periods (typical for Paris)
    construction_periods = [
        ("0", "1900"),     # Pré-1900
        ("1901", "1945"),  # Pré-guerre
        ("1946", "1970"),  # Reconstruction
        ("1971", "1990"),  # Fin du XXe siècle
        ("1991", "2010"),  # Début du XXIe siècle
        ("2011", "2023")   # Construction récente
    ]
    
    # Diagnostician's time of visit
    years = list(range(2021, 2026))  # From 2021 to 2025
    months = list(range(1, 13))      # 12 months
    
    total_segments = len(postal_codes) * len(construction_periods) * len(years) * len(months)
    segment_count = 0
    
    # Requesting the API (segmenting the calls)

    for code in postal_codes:
        for start_year, end_year in construction_periods:
            for year in years:
                for month in months:
                    segment_count += 1
                    month_str = str(month).zfill(2)
                    
                    print(f"\nFetching segment {segment_count}/{total_segments}")
                    print(f"Postal code: {code}, period: {start_year}-{end_year}, visit date: {year}-{month_str}")
                    
                    batch_size = 5000
                    offset = 0
                    
                    while True:
                        url = 'https://data.ademe.fr/data-fair/api/v1/datasets/dpe03existant/lines'
                        headers = {
                                'accept': 'application/json',
                                'x-apikey': API_KEY
                        }
                        params = {
                            'size': batch_size,
                            'skip': offset,
                            'select': '_geopoint,adresse_ban,annee_construction,numero_dpe,etiquette_dpe,etiquette_ges,conso_5_usages_par_m2_ef,emission_ges_5_usages_par_m2,categorie_enr,date_visite_diagnostiqueur',
                            'qs': f'code_postal_ban:{code} AND annee_construction:>={start_year} AND annee_construction:<={end_year} AND date_visite_diagnostiqueur:>={year}-{month_str}-01 AND date_visite_diagnostiqueur:<={year}-{month_str}-31'
                        }
                        
                        response = requests.get(url, headers=headers, params=params)
                        
                        if response.status_code != 200:
                            print(f"HTTP Error: {response.status_code}")
                            print(f"Response: {response.text}")
                            break
                            
                        try:
                            data = response.json()
                            batch = data.get("results", [])
                            
                            if not batch:  # If no results
                                print(f"No results for this segment")
                                break
                            
                            # Converting to DataFrame and adding to the final DataFrame
                            batch_df = pd.DataFrame(batch)
                            final_df = pd.concat([final_df, batch_df], ignore_index=True)
                            
                            total_for_segment = data.get('total', 0)
                            print(f"Total records so far: {len(final_df)}")
                            print(f"Records for this segment: {offset + len(batch)}/{total_for_segment}")
                            
                            if len(batch) < batch_size or offset + len(batch) >= total_for_segment:
                                print(f"All data retrieved for this segment")
                                break
                                
                            offset += len(batch)
                            
                            # Limit checking
                            if offset + batch_size > 10000:
                                print(f"Reached API limit for this segment, moving to next")
                                break
                                
                        except json.JSONDecodeError as e:
                            print(f"JSON decoding error for this segment, offset {offset}")
                            print(f"Response: {response.text[:200]}...")
                            break
    
    # Temporary backup every 50000 records to avoid restarting from scratch in case of problem
    if len(final_df) > 0 and len(final_df) % 50000 < 5000:
        temp_filename = f"dpe_paris_temp_{len(final_df)}.csv"
        final_df.to_csv(temp_filename, index=False)
        print(f"Intermediate save: {temp_filename}")
    
    print(f"\nFetching completed. Total: {len(final_df)} recordings")
    return final_df

# Running the main function
df = get_all_dpe_data()
print(f"\nFinal DataFrame's shape: {df.shape}")
# Out:
# Fetching segment 1/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-01
# No results for this segment
#
# Fetching segment 2/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-02
# No results for this segment
#
# Fetching segment 3/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-03
# No results for this segment
#
# Fetching segment 4/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-04
# No results for this segment
#
# Fetching segment 5/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-05
# No results for this segment
#
# Fetching segment 6/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-06
# No results for this segment
#
# Fetching segment 7/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-07
# Total records so far: 1
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 8/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-08
# Total records so far: 3
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 9/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-09
# Total records so far: 15
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 10/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-10
# Total records so far: 22
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 11/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-11
# Total records so far: 36
# Records for this segment: 14/14
# All data retrieved for this segment
#
# Fetching segment 12/7200
# Postal code: 75001, period: 0-1900, visit date: 2021-12
# Total records so far: 45
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 13/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-01
# Total records so far: 58
# Records for this segment: 13/13
# All data retrieved for this segment
#
# Fetching segment 14/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-02
# Total records so far: 76
# Records for this segment: 18/18
# All data retrieved for this segment
#
# Fetching segment 15/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-03
# Total records so far: 90
# Records for this segment: 14/14
# All data retrieved for this segment
#
# Fetching segment 16/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-04
# Total records so far: 99
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 17/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-05
# Total records so far: 110
# Records for this segment: 11/11
# All data retrieved for this segment
#
# Fetching segment 18/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-06
# Total records so far: 151
# Records for this segment: 41/41
# All data retrieved for this segment
#
# Fetching segment 19/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-07
# Total records so far: 162
# Records for this segment: 11/11
# All data retrieved for this segment
#
# Fetching segment 20/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-08
# Total records so far: 169
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 21/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-09
# Total records so far: 184
# Records for this segment: 15/15
# All data retrieved for this segment
#
# Fetching segment 22/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-10
# Total records so far: 195
# Records for this segment: 11/11
# All data retrieved for this segment
#
# Fetching segment 23/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-11
# Total records so far: 219
# Records for this segment: 24/24
# All data retrieved for this segment
#
# Fetching segment 24/7200
# Postal code: 75001, period: 0-1900, visit date: 2022-12
# Total records so far: 245
# Records for this segment: 26/26
# All data retrieved for this segment
#
# Fetching segment 25/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-01
# Total records so far: 260
# Records for this segment: 15/15
# All data retrieved for this segment
#
# Fetching segment 26/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-02
# Total records so far: 299
# Records for this segment: 39/39
# All data retrieved for this segment
#
# Fetching segment 27/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-03
# Total records so far: 315
# Records for this segment: 16/16
# All data retrieved for this segment
#
# Fetching segment 28/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-04
# Total records so far: 357
# Records for this segment: 42/42
# All data retrieved for this segment
#
# Fetching segment 29/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-05
# Total records so far: 383
# Records for this segment: 26/26
# All data retrieved for this segment
#
# Fetching segment 30/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-06
# Total records so far: 415
# Records for this segment: 32/32
# All data retrieved for this segment
#
# Fetching segment 31/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-07
# Total records so far: 458
# Records for this segment: 43/43
# All data retrieved for this segment
#
# Fetching segment 32/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-08
# Total records so far: 464
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 33/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-09
# Total records so far: 484
# Records for this segment: 20/20
# All data retrieved for this segment
#
# Fetching segment 34/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-10
# Total records so far: 498
# Records for this segment: 14/14
# All data retrieved for this segment
#
# Fetching segment 35/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-11
# Total records so far: 517
# Records for this segment: 19/19
# All data retrieved for this segment
#
# Fetching segment 36/7200
# Postal code: 75001, period: 0-1900, visit date: 2023-12
# Total records so far: 535
# Records for this segment: 18/18
# All data retrieved for this segment
#
# Fetching segment 37/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-01
# Total records so far: 568
# Records for this segment: 33/33
# All data retrieved for this segment
#
# Fetching segment 38/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-02
# Total records so far: 596
# Records for this segment: 28/28
# All data retrieved for this segment
#
# Fetching segment 39/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-03
# Total records so far: 627
# Records for this segment: 31/31
# All data retrieved for this segment
#
# Fetching segment 40/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-04
# Total records so far: 646
# Records for this segment: 19/19
# All data retrieved for this segment
#
# Fetching segment 41/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-05
# Total records so far: 662
# Records for this segment: 16/16
# All data retrieved for this segment
#
# Fetching segment 42/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-06
# Total records so far: 677
# Records for this segment: 15/15
# All data retrieved for this segment
#
# Fetching segment 43/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-07
# Total records so far: 696
# Records for this segment: 19/19
# All data retrieved for this segment
#
# Fetching segment 44/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-08
# Total records so far: 702
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 45/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-09
# Total records so far: 777
# Records for this segment: 75/75
# All data retrieved for this segment
#
# Fetching segment 46/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-10
# Total records so far: 789
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 47/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-11
# Total records so far: 801
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 48/7200
# Postal code: 75001, period: 0-1900, visit date: 2024-12
# Total records so far: 811
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 49/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-01
# Total records so far: 829
# Records for this segment: 18/18
# All data retrieved for this segment
#
# Fetching segment 50/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-02
# Total records so far: 866
# Records for this segment: 37/37
# All data retrieved for this segment
#
# Fetching segment 51/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-03
# Total records so far: 889
# Records for this segment: 23/23
# All data retrieved for this segment
#
# Fetching segment 52/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-04
# Total records so far: 894
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 53/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-05
# No results for this segment
#
# Fetching segment 54/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-06
# No results for this segment
#
# Fetching segment 55/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-07
# No results for this segment
#
# Fetching segment 56/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-08
# No results for this segment
#
# Fetching segment 57/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-09
# No results for this segment
#
# Fetching segment 58/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-10
# No results for this segment
#
# Fetching segment 59/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-11
# No results for this segment
#
# Fetching segment 60/7200
# Postal code: 75001, period: 0-1900, visit date: 2025-12
# No results for this segment
#
# Fetching segment 61/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-01
# No results for this segment
#
# Fetching segment 62/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-02
# No results for this segment
#
# Fetching segment 63/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-03
# No results for this segment
#
# Fetching segment 64/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-04
# No results for this segment
#
# Fetching segment 65/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-05
# No results for this segment
#
# Fetching segment 66/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-06
# No results for this segment
#
# Fetching segment 67/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-07
# Total records so far: 899
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 68/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-08
# Total records so far: 903
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 69/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-09
# Total records so far: 905
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 70/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-10
# Total records so far: 910
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 71/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-11
# Total records so far: 917
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 72/7200
# Postal code: 75001, period: 1901-1945, visit date: 2021-12
# Total records so far: 921
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 73/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-01
# Total records so far: 924
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 74/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-02
# Total records so far: 934
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 75/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-03
# Total records so far: 938
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 76/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-04
# Total records so far: 942
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 77/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-05
# Total records so far: 950
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 78/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-06
# Total records so far: 954
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 79/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-07
# Total records so far: 967
# Records for this segment: 13/13
# All data retrieved for this segment
#
# Fetching segment 80/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-08
# Total records so far: 968
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 81/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-09
# Total records so far: 978
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 82/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-10
# Total records so far: 982
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 83/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-11
# Total records so far: 988
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 84/7200
# Postal code: 75001, period: 1901-1945, visit date: 2022-12
# Total records so far: 996
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 85/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-01
# Total records so far: 1008
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 86/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-02
# Total records so far: 1013
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 87/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-03
# Total records so far: 1053
# Records for this segment: 40/40
# All data retrieved for this segment
#
# Fetching segment 88/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-04
# Total records so far: 1055
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 89/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-05
# Total records so far: 1064
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 90/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-06
# Total records so far: 1072
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 91/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-07
# Total records so far: 1075
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 92/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-08
# Total records so far: 1082
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 93/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-09
# Total records so far: 1090
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 94/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-10
# Total records so far: 1121
# Records for this segment: 31/31
# All data retrieved for this segment
#
# Fetching segment 95/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-11
# Total records so far: 1130
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 96/7200
# Postal code: 75001, period: 1901-1945, visit date: 2023-12
# Total records so far: 1134
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 97/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-01
# Total records so far: 1151
# Records for this segment: 17/17
# All data retrieved for this segment
#
# Fetching segment 98/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-02
# Total records so far: 1157
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 99/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-03
# Total records so far: 1165
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 100/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-04
# Total records so far: 1170
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 101/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-05
# Total records so far: 1177
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 102/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-06
# Total records so far: 1185
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 103/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-07
# Total records so far: 1193
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 104/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-08
# Total records so far: 1197
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 105/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-09
# Total records so far: 1200
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 106/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-10
# Total records so far: 1209
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 107/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-11
# Total records so far: 1212
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 108/7200
# Postal code: 75001, period: 1901-1945, visit date: 2024-12
# Total records so far: 1213
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 109/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-01
# Total records so far: 1223
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 110/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-02
# Total records so far: 1252
# Records for this segment: 29/29
# All data retrieved for this segment
#
# Fetching segment 111/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-03
# Total records so far: 1262
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 112/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-04
# No results for this segment
#
# Fetching segment 113/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-05
# No results for this segment
#
# Fetching segment 114/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-06
# No results for this segment
#
# Fetching segment 115/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-07
# No results for this segment
#
# Fetching segment 116/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-08
# No results for this segment
#
# Fetching segment 117/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-09
# No results for this segment
#
# Fetching segment 118/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-10
# No results for this segment
#
# Fetching segment 119/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-11
# No results for this segment
#
# Fetching segment 120/7200
# Postal code: 75001, period: 1901-1945, visit date: 2025-12
# No results for this segment
#
# Fetching segment 121/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-01
# No results for this segment
#
# Fetching segment 122/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-02
# No results for this segment
#
# Fetching segment 123/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-03
# No results for this segment
#
# Fetching segment 124/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-04
# No results for this segment
#
# Fetching segment 125/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-05
# No results for this segment
#
# Fetching segment 126/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-06
# Total records so far: 1265
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 127/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-07
# Total records so far: 1305
# Records for this segment: 40/40
# All data retrieved for this segment
#
# Fetching segment 128/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-08
# Total records so far: 1344
# Records for this segment: 39/39
# All data retrieved for this segment
#
# Fetching segment 129/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-09
# Total records so far: 1399
# Records for this segment: 55/55
# All data retrieved for this segment
#
# Fetching segment 130/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-10
# Total records so far: 1427
# Records for this segment: 28/28
# All data retrieved for this segment
#
# Fetching segment 131/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-11
# Total records so far: 1460
# Records for this segment: 33/33
# All data retrieved for this segment
#
# Fetching segment 132/7200
# Postal code: 75001, period: 1946-1970, visit date: 2021-12
# Total records so far: 1492
# Records for this segment: 32/32
# All data retrieved for this segment
#
# Fetching segment 133/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-01
# Total records so far: 1545
# Records for this segment: 53/53
# All data retrieved for this segment
#
# Fetching segment 134/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-02
# Total records so far: 1584
# Records for this segment: 39/39
# All data retrieved for this segment
#
# Fetching segment 135/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-03
# Total records so far: 1641
# Records for this segment: 57/57
# All data retrieved for this segment
#
# Fetching segment 136/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-04
# Total records so far: 1732
# Records for this segment: 91/91
# All data retrieved for this segment
#
# Fetching segment 137/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-05
# Total records so far: 1739
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 138/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-06
# Total records so far: 1751
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 139/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-07
# Total records so far: 1766
# Records for this segment: 15/15
# All data retrieved for this segment
#
# Fetching segment 140/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-08
# Total records so far: 1772
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 141/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-09
# Total records so far: 1783
# Records for this segment: 11/11
# All data retrieved for this segment
#
# Fetching segment 142/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-10
# Total records so far: 1811
# Records for this segment: 28/28
# All data retrieved for this segment
#
# Fetching segment 143/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-11
# Total records so far: 1815
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 144/7200
# Postal code: 75001, period: 1946-1970, visit date: 2022-12
# Total records so far: 1829
# Records for this segment: 14/14
# All data retrieved for this segment
#
# Fetching segment 145/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-01
# Total records so far: 1836
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 146/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-02
# Total records so far: 1862
# Records for this segment: 26/26
# All data retrieved for this segment
#
# Fetching segment 147/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-03
# Total records so far: 1874
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 148/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-04
# Total records so far: 1884
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 149/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-05
# Total records so far: 1890
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 150/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-06
# Total records so far: 1899
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 151/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-07
# Total records so far: 1907
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 152/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-08
# Total records so far: 1910
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 153/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-09
# Total records so far: 1920
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 154/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-10
# Total records so far: 1925
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 155/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-11
# Total records so far: 1945
# Records for this segment: 20/20
# All data retrieved for this segment
#
# Fetching segment 156/7200
# Postal code: 75001, period: 1946-1970, visit date: 2023-12
# Total records so far: 1952
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 157/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-01
# Total records so far: 1961
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 158/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-02
# Total records so far: 1970
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 159/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-03
# Total records so far: 1979
# Records for this segment: 9/9
# All data retrieved for this segment
#
# Fetching segment 160/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-04
# Total records so far: 1999
# Records for this segment: 20/20
# All data retrieved for this segment
#
# Fetching segment 161/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-05
# Total records so far: 2005
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 162/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-06
# Total records so far: 2023
# Records for this segment: 18/18
# All data retrieved for this segment
#
# Fetching segment 163/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-07
# Total records so far: 2031
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 164/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-08
# Total records so far: 2033
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 165/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-09
# Total records so far: 2041
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 166/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-10
# Total records so far: 2046
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 167/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-11
# Total records so far: 2053
# Records for this segment: 7/7
# All data retrieved for this segment
#
# Fetching segment 168/7200
# Postal code: 75001, period: 1946-1970, visit date: 2024-12
# Total records so far: 2063
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 169/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-01
# Total records so far: 2068
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 170/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-02
# Total records so far: 2076
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 171/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-03
# Total records so far: 2080
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 172/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-04
# No results for this segment
#
# Fetching segment 173/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-05
# No results for this segment
#
# Fetching segment 174/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-06
# No results for this segment
#
# Fetching segment 175/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-07
# No results for this segment
#
# Fetching segment 176/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-08
# No results for this segment
#
# Fetching segment 177/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-09
# No results for this segment
#
# Fetching segment 178/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-10
# No results for this segment
#
# Fetching segment 179/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-11
# No results for this segment
#
# Fetching segment 180/7200
# Postal code: 75001, period: 1946-1970, visit date: 2025-12
# No results for this segment
#
# Fetching segment 181/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-01
# No results for this segment
#
# Fetching segment 182/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-02
# No results for this segment
#
# Fetching segment 183/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-03
# No results for this segment
#
# Fetching segment 184/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-04
# No results for this segment
#
# Fetching segment 185/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-05
# No results for this segment
#
# Fetching segment 186/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-06
# No results for this segment
#
# Fetching segment 187/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-07
# No results for this segment
#
# Fetching segment 188/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-08
# No results for this segment
#
# Fetching segment 189/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-09
# Total records so far: 2081
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 190/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-10
# No results for this segment
#
# Fetching segment 191/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-11
# Total records so far: 2094
# Records for this segment: 13/13
# All data retrieved for this segment
#
# Fetching segment 192/7200
# Postal code: 75001, period: 1971-1990, visit date: 2021-12
# Total records so far: 2095
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 193/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-01
# Total records so far: 2097
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 194/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-02
# Total records so far: 2099
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 195/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-03
# Total records so far: 2101
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 196/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-04
# No results for this segment
#
# Fetching segment 197/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-05
# No results for this segment
#
# Fetching segment 198/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-06
# No results for this segment
#
# Fetching segment 199/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-07
# Total records so far: 2107
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 200/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-08
# No results for this segment
#
# Fetching segment 201/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-09
# No results for this segment
#
# Fetching segment 202/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-10
# Total records so far: 2110
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 203/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-11
# Total records so far: 2112
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 204/7200
# Postal code: 75001, period: 1971-1990, visit date: 2022-12
# No results for this segment
#
# Fetching segment 205/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-01
# No results for this segment
#
# Fetching segment 206/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-02
# No results for this segment
#
# Fetching segment 207/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-03
# Total records so far: 2115
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 208/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-04
# No results for this segment
#
# Fetching segment 209/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-05
# No results for this segment
#
# Fetching segment 210/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-06
# No results for this segment
#
# Fetching segment 211/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-07
# No results for this segment
#
# Fetching segment 212/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-08
# No results for this segment
#
# Fetching segment 213/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-09
# Total records so far: 2116
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 214/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-10
# Total records so far: 2117
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 215/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-11
# No results for this segment
#
# Fetching segment 216/7200
# Postal code: 75001, period: 1971-1990, visit date: 2023-12
# No results for this segment
#
# Fetching segment 217/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-01
# No results for this segment
#
# Fetching segment 218/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-02
# Total records so far: 2118
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 219/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-03
# No results for this segment
#
# Fetching segment 220/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-04
# Total records so far: 2372
# Records for this segment: 254/254
# All data retrieved for this segment
#
# Fetching segment 221/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-05
# No results for this segment
#
# Fetching segment 222/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-06
# No results for this segment
#
# Fetching segment 223/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-07
# Total records so far: 2373
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 224/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-08
# No results for this segment
#
# Fetching segment 225/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-09
# No results for this segment
#
# Fetching segment 226/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-10
# No results for this segment
#
# Fetching segment 227/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-11
# Total records so far: 2374
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 228/7200
# Postal code: 75001, period: 1971-1990, visit date: 2024-12
# Total records so far: 2375
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 229/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-01
# No results for this segment
#
# Fetching segment 230/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-02
# No results for this segment
#
# Fetching segment 231/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-03
# No results for this segment
#
# Fetching segment 232/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-04
# No results for this segment
#
# Fetching segment 233/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-05
# No results for this segment
#
# Fetching segment 234/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-06
# No results for this segment
#
# Fetching segment 235/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-07
# No results for this segment
#
# Fetching segment 236/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-08
# No results for this segment
#
# Fetching segment 237/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-09
# No results for this segment
#
# Fetching segment 238/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-10
# No results for this segment
#
# Fetching segment 239/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-11
# No results for this segment
#
# Fetching segment 240/7200
# Postal code: 75001, period: 1971-1990, visit date: 2025-12
# No results for this segment
#
# Fetching segment 241/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-01
# No results for this segment
#
# Fetching segment 242/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-02
# No results for this segment
#
# Fetching segment 243/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-03
# No results for this segment
#
# Fetching segment 244/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-04
# No results for this segment
#
# Fetching segment 245/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-05
# No results for this segment
#
# Fetching segment 246/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-06
# No results for this segment
#
# Fetching segment 247/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-07
# No results for this segment
#
# Fetching segment 248/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-08
# No results for this segment
#
# Fetching segment 249/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-09
# No results for this segment
#
# Fetching segment 250/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-10
# No results for this segment
#
# Fetching segment 251/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-11
# No results for this segment
#
# Fetching segment 252/7200
# Postal code: 75001, period: 1991-2010, visit date: 2021-12
# Total records so far: 2376
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 253/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-01
# No results for this segment
#
# Fetching segment 254/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-02
# No results for this segment
#
# Fetching segment 255/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-03
# No results for this segment
#
# Fetching segment 256/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-04
# No results for this segment
#
# Fetching segment 257/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-05
# No results for this segment
#
# Fetching segment 258/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-06
# No results for this segment
#
# Fetching segment 259/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-07
# No results for this segment
#
# Fetching segment 260/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-08
# No results for this segment
#
# Fetching segment 261/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-09
# Total records so far: 2377
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 262/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-10
# No results for this segment
#
# Fetching segment 263/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-11
# Total records so far: 2378
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 264/7200
# Postal code: 75001, period: 1991-2010, visit date: 2022-12
# No results for this segment
#
# Fetching segment 265/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-01
# No results for this segment
#
# Fetching segment 266/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-02
# Total records so far: 2379
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 267/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-03
# No results for this segment
#
# Fetching segment 268/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-04
# No results for this segment
#
# Fetching segment 269/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-05
# No results for this segment
#
# Fetching segment 270/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-06
# Total records so far: 2387
# Records for this segment: 8/8
# All data retrieved for this segment
#
# Fetching segment 271/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-07
# No results for this segment
#
# Fetching segment 272/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-08
# No results for this segment
#
# Fetching segment 273/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-09
# No results for this segment
#
# Fetching segment 274/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-10
# No results for this segment
#
# Fetching segment 275/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-11
# No results for this segment
#
# Fetching segment 276/7200
# Postal code: 75001, period: 1991-2010, visit date: 2023-12
# No results for this segment
#
# Fetching segment 277/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-01
# No results for this segment
#
# Fetching segment 278/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-02
# No results for this segment
#
# Fetching segment 279/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-03
# Total records so far: 2388
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 280/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-04
# No results for this segment
#
# Fetching segment 281/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-05
# Total records so far: 2389
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 282/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-06
# Total records so far: 2390
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 283/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-07
# Total records so far: 2391
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 284/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-08
# Total records so far: 2392
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 285/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-09
# Total records so far: 2393
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 286/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-10
# Total records so far: 2394
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 287/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-11
# No results for this segment
#
# Fetching segment 288/7200
# Postal code: 75001, period: 1991-2010, visit date: 2024-12
# Total records so far: 2396
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 289/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-01
# No results for this segment
#
# Fetching segment 290/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-02
# No results for this segment
#
# Fetching segment 291/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-03
# Total records so far: 2397
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 292/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-04
# No results for this segment
#
# Fetching segment 293/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-05
# No results for this segment
#
# Fetching segment 294/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-06
# No results for this segment
#
# Fetching segment 295/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-07
# No results for this segment
#
# Fetching segment 296/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-08
# No results for this segment
#
# Fetching segment 297/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-09
# No results for this segment
#
# Fetching segment 298/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-10
# No results for this segment
#
# Fetching segment 299/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-11
# No results for this segment
#
# Fetching segment 300/7200
# Postal code: 75001, period: 1991-2010, visit date: 2025-12
# No results for this segment
#
# Fetching segment 301/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-01
# No results for this segment
#
# Fetching segment 302/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-02
# No results for this segment
#
# Fetching segment 303/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-03
# No results for this segment
#
# Fetching segment 304/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-04
# No results for this segment
#
# Fetching segment 305/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-05
# No results for this segment
#
# Fetching segment 306/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-06
# No results for this segment
#
# Fetching segment 307/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-07
# No results for this segment
#
# Fetching segment 308/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-08
# No results for this segment
#
# Fetching segment 309/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-09
# No results for this segment
#
# Fetching segment 310/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-10
# No results for this segment
#
# Fetching segment 311/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-11
# No results for this segment
#
# Fetching segment 312/7200
# Postal code: 75001, period: 2011-2023, visit date: 2021-12
# No results for this segment
#
# Fetching segment 313/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-01
# No results for this segment
#
# Fetching segment 314/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-02
# No results for this segment
#
# Fetching segment 315/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-03
# Total records so far: 2398
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 316/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-04
# No results for this segment
#
# Fetching segment 317/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-05
# No results for this segment
#
# Fetching segment 318/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-06
# Total records so far: 2399
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 319/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-07
# No results for this segment
#
# Fetching segment 320/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-08
# No results for this segment
#
# Fetching segment 321/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-09
# No results for this segment
#
# Fetching segment 322/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-10
# No results for this segment
#
# Fetching segment 323/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-11
# Total records so far: 2400
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 324/7200
# Postal code: 75001, period: 2011-2023, visit date: 2022-12
# No results for this segment
#
# Fetching segment 325/7200
# Postal code: 75001, period: 2011-2023, visit date: 2023-01
# Total records so far: 2401
# Records for this segment: 1/1
# ...
# Total records so far: 348451
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 7105/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-01
# Total records so far: 348511
# Records for this segment: 60/60
# All data retrieved for this segment
#
# Fetching segment 7106/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-02
# Total records so far: 348530
# Records for this segment: 19/19
# All data retrieved for this segment
#
# Fetching segment 7107/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-03
# Total records so far: 348588
# Records for this segment: 58/58
# All data retrieved for this segment
#
# Fetching segment 7108/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-04
# Total records so far: 348747
# Records for this segment: 159/159
# All data retrieved for this segment
#
# Fetching segment 7109/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-05
# Total records so far: 348759
# Records for this segment: 12/12
# All data retrieved for this segment
#
# Fetching segment 7110/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-06
# Total records so far: 348822
# Records for this segment: 63/63
# All data retrieved for this segment
#
# Fetching segment 7111/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-07
# Total records so far: 349027
# Records for this segment: 205/205
# All data retrieved for this segment
#
# Fetching segment 7112/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-08
# Total records so far: 349072
# Records for this segment: 45/45
# All data retrieved for this segment
#
# Fetching segment 7113/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-09
# Total records so far: 349141
# Records for this segment: 69/69
# All data retrieved for this segment
#
# Fetching segment 7114/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-10
# Total records so far: 349500
# Records for this segment: 359/359
# All data retrieved for this segment
#
# Fetching segment 7115/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-11
# Total records so far: 349562
# Records for this segment: 62/62
# All data retrieved for this segment
#
# Fetching segment 7116/7200
# Postal code: 75020, period: 1991-2010, visit date: 2023-12
# Total records so far: 349583
# Records for this segment: 21/21
# All data retrieved for this segment
#
# Fetching segment 7117/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-01
# Total records so far: 349666
# Records for this segment: 83/83
# All data retrieved for this segment
#
# Fetching segment 7118/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-02
# Total records so far: 349692
# Records for this segment: 26/26
# All data retrieved for this segment
#
# Fetching segment 7119/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-03
# Total records so far: 349899
# Records for this segment: 207/207
# All data retrieved for this segment
#
# Fetching segment 7120/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-04
# Total records so far: 350375
# Records for this segment: 476/476
# All data retrieved for this segment
#
# Fetching segment 7121/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-05
# Total records so far: 351351
# Records for this segment: 976/976
# All data retrieved for this segment
#
# Fetching segment 7122/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-06
# Total records so far: 351864
# Records for this segment: 513/513
# All data retrieved for this segment
#
# Fetching segment 7123/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-07
# Total records so far: 352458
# Records for this segment: 594/594
# All data retrieved for this segment
#
# Fetching segment 7124/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-08
# Total records so far: 352546
# Records for this segment: 88/88
# All data retrieved for this segment
#
# Fetching segment 7125/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-09
# Total records so far: 353131
# Records for this segment: 585/585
# All data retrieved for this segment
#
# Fetching segment 7126/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-10
# Total records so far: 353466
# Records for this segment: 335/335
# All data retrieved for this segment
#
# Fetching segment 7127/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-11
# Total records so far: 353582
# Records for this segment: 116/116
# All data retrieved for this segment
#
# Fetching segment 7128/7200
# Postal code: 75020, period: 1991-2010, visit date: 2024-12
# Total records so far: 353645
# Records for this segment: 63/63
# All data retrieved for this segment
#
# Fetching segment 7129/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-01
# Total records so far: 353721
# Records for this segment: 76/76
# All data retrieved for this segment
#
# Fetching segment 7130/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-02
# Total records so far: 353891
# Records for this segment: 170/170
# All data retrieved for this segment
#
# Fetching segment 7131/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-03
# Total records so far: 353901
# Records for this segment: 10/10
# All data retrieved for this segment
#
# Fetching segment 7132/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-04
# No results for this segment
#
# Fetching segment 7133/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-05
# No results for this segment
#
# Fetching segment 7134/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-06
# No results for this segment
#
# Fetching segment 7135/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-07
# No results for this segment
#
# Fetching segment 7136/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-08
# No results for this segment
#
# Fetching segment 7137/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-09
# No results for this segment
#
# Fetching segment 7138/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-10
# No results for this segment
#
# Fetching segment 7139/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-11
# No results for this segment
#
# Fetching segment 7140/7200
# Postal code: 75020, period: 1991-2010, visit date: 2025-12
# No results for this segment
#
# Fetching segment 7141/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-01
# No results for this segment
#
# Fetching segment 7142/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-02
# No results for this segment
#
# Fetching segment 7143/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-03
# No results for this segment
#
# Fetching segment 7144/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-04
# No results for this segment
#
# Fetching segment 7145/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-05
# No results for this segment
#
# Fetching segment 7146/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-06
# No results for this segment
#
# Fetching segment 7147/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-07
# No results for this segment
#
# Fetching segment 7148/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-08
# Total records so far: 353905
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 7149/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-09
# Total records so far: 353907
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 7150/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-10
# Total records so far: 353913
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 7151/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-11
# Total records so far: 353916
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 7152/7200
# Postal code: 75020, period: 2011-2023, visit date: 2021-12
# Total records so far: 353917
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 7153/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-01
# No results for this segment
#
# Fetching segment 7154/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-02
# Total records so far: 353918
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 7155/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-03
# Total records so far: 353924
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 7156/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-04
# Total records so far: 353926
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 7157/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-05
# Total records so far: 353930
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 7158/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-06
# Total records so far: 353934
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 7159/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-07
# Total records so far: 353935
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 7160/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-08
# No results for this segment
#
# Fetching segment 7161/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-09
# Total records so far: 353938
# Records for this segment: 3/3
# All data retrieved for this segment
#
# Fetching segment 7162/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-10
# Total records so far: 353944
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 7163/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-11
# Total records so far: 353950
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 7164/7200
# Postal code: 75020, period: 2011-2023, visit date: 2022-12
# Total records so far: 353952
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 7165/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-01
# Total records so far: 353957
# Records for this segment: 5/5
# All data retrieved for this segment
#
# Fetching segment 7166/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-02
# Total records so far: 353961
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 7167/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-03
# Total records so far: 353982
# Records for this segment: 21/21
# All data retrieved for this segment
#
# Fetching segment 7168/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-04
# Total records so far: 353999
# Records for this segment: 17/17
# All data retrieved for this segment
#
# Fetching segment 7169/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-05
# Total records so far: 354000
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 7170/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-06
# Total records so far: 354090
# Records for this segment: 90/90
# All data retrieved for this segment
#
# Fetching segment 7171/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-07
# Total records so far: 354096
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 7172/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-08
# Total records so far: 354102
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 7173/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-09
# Total records so far: 354204
# Records for this segment: 102/102
# All data retrieved for this segment
#
# Fetching segment 7174/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-10
# Total records so far: 354206
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 7175/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-11
# Total records so far: 354217
# Records for this segment: 11/11
# All data retrieved for this segment
#
# Fetching segment 7176/7200
# Postal code: 75020, period: 2011-2023, visit date: 2023-12
# Total records so far: 354219
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 7177/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-01
# Total records so far: 354221
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 7178/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-02
# Total records so far: 354222
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 7179/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-03
# Total records so far: 354226
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 7180/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-04
# Total records so far: 354232
# Records for this segment: 6/6
# All data retrieved for this segment
#
# Fetching segment 7181/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-05
# Total records so far: 354285
# Records for this segment: 53/53
# All data retrieved for this segment
#
# Fetching segment 7182/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-06
# Total records so far: 354312
# Records for this segment: 27/27
# All data retrieved for this segment
#
# Fetching segment 7183/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-07
# Total records so far: 354355
# Records for this segment: 43/43
# All data retrieved for this segment
#
# Fetching segment 7184/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-08
# Total records so far: 354384
# Records for this segment: 29/29
# All data retrieved for this segment
#
# Fetching segment 7185/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-09
# Total records so far: 354416
# Records for this segment: 32/32
# All data retrieved for this segment
#
# Fetching segment 7186/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-10
# Total records so far: 354544
# Records for this segment: 128/128
# All data retrieved for this segment
#
# Fetching segment 7187/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-11
# Total records so far: 354572
# Records for this segment: 28/28
# All data retrieved for this segment
#
# Fetching segment 7188/7200
# Postal code: 75020, period: 2011-2023, visit date: 2024-12
# Total records so far: 354637
# Records for this segment: 65/65
# All data retrieved for this segment
#
# Fetching segment 7189/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-01
# Total records so far: 354641
# Records for this segment: 4/4
# All data retrieved for this segment
#
# Fetching segment 7190/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-02
# Total records so far: 354643
# Records for this segment: 2/2
# All data retrieved for this segment
#
# Fetching segment 7191/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-03
# Total records so far: 354644
# Records for this segment: 1/1
# All data retrieved for this segment
#
# Fetching segment 7192/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-04
# No results for this segment
#
# Fetching segment 7193/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-05
# No results for this segment
#
# Fetching segment 7194/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-06
# No results for this segment
#
# Fetching segment 7195/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-07
# No results for this segment
#
# Fetching segment 7196/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-08
# No results for this segment
#
# Fetching segment 7197/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-09
# No results for this segment
#
# Fetching segment 7198/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-10
# No results for this segment
#
# Fetching segment 7199/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-11
# No results for this segment
#
# Fetching segment 7200/7200
# Postal code: 75020, period: 2011-2023, visit date: 2025-12
# No results for this segment
# Intermediate save: dpe_paris_temp_354644.csv
#
# Fetching completed. Total: 354644 recordings
#
# Final DataFrame's shape: (354644, 11)

# %% [markdown]
# ### Checking imported data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354644 entries, 0 to 354643
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   _geopoint                     354644 non-null  object
#  1   adresse_ban                   354450 non-null  object
#  2   annee_construction            354644 non-null  object
#  3   numero_dpe                    354644 non-null  object
#  4   etiquette_dpe                 354644 non-null  object
#  5   etiquette_ges                 354644 non-null  object
#  6   conso_5_usages_par_m2_ef      354643 non-null  object
#  7   emission_ges_5_usages_par_m2  354643 non-null  object
#  8   categorie_enr                 72462 non-null   object
#  9   date_visite_diagnostiqueur    354644 non-null  object
#  10  _score                        0 non-null       object
# dtypes: object(11)
# memory usage: 29.8+ MB

# %%
df.head()
# Out:
#                                _geopoint                  adresse_ban  \
# 0   48.86595400777677,2.3354320257122905  Rue Sainte-Anne 75001 Paris
# 1   48.860345970770695,2.343468977763066   3 Rue du Roule 75001 Paris
# 2  48.864780089917204,2.3411900768347564     5 Rue Hérold 75001 Paris
# 3    48.86435902854955,2.342206030505405  5 Rue Coq Héron 75001 Paris
# 4  48.865052440555104,2.3295030329353708    3 Rue d’Alger 75001 Paris
#
#   annee_construction     numero_dpe etiquette_dpe etiquette_ges  \
# 0               1900  2275E0012511D             E             B
# 1               1850  2175E0136723M             F             C
# 2               1850  2175E0230740N             F             C
# 3               1850  2175E1032152B             E             D
# 4               1830  2175E0320904J             D             B
#
#   conso_5_usages_par_m2_ef emission_ges_5_usages_par_m2 categorie_enr  \
# 0                      143                           10           NaN
# 1                    152.9                         11.5           NaN
# 2                    153.9                         11.0           NaN
# 3                    197.0                         35.9           NaN
# 4                    106.3                          8.0           NaN
#
#   date_visite_diagnostiqueur _score
# 0                 2021-07-07   None
# 1                 2021-08-02   None
# 2                 2021-08-29   None
# 3                 2021-09-13   None
# 4                 2021-09-13   None

# %% [markdown]
# ### Exporting data to a .csv

# %%
df.to_csv("dpe_logements_existants_21_ademe.csv")
