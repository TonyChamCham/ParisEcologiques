# %% [markdown]
# ## Listing of Paris' cycles lanes, with location, length and export date.

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Connecting to Paris Data's API (and testing the response's status code)

# %%
params = {"select":"*"}
response = requests.get('https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/amenagements-cyclables/records?',params=params)
response.status_code
# Out:
# 200

# %%
pd.DataFrame(response.json()["results"])
# Out:
#      osm_id                             nom                  amenagement  \
# 0  30410514                    Rue de Patay               bande cyclable
# 1  30622365              Passage Saint-Roch                voie piétonne
# 2  31142990         Rue de l'Armée d'Orient               bande cyclable
# 3  32082859         Rue de la Tombe Issoire  double-sens cyclable simple
# 4  32696192         Passage de la Main d'Or  double-sens cyclable simple
# 5  32748823                 Passage Pouchet                voie piétonne
# 6  32749218             Rue de la Jonquière  double-sens cyclable simple
# 7  32810258              Rue des Solitaires                voie piétonne
# 8  34335471  Passage du Buisson Saint-Louis  double-sens cyclable simple
# 9  34386506                    Rue Chauchat               bande cyclable
#
#   cote_amenagement                       sens surface arrondissement bois  \
# 0           gauche  sens contraire de la voie    None             13  non
# 1           gauche  sens contraire de la voie    None              1  non
# 2           gauche      même sens que la voie    None             18  non
# 3           gauche      même sens que la voie    None             14  non
# 4           gauche      même sens que la voie    None             11  non
# 5           gauche      même sens que la voie    None             17  non
# 6           gauche      même sens que la voie    None             17  non
# 7           gauche  sens contraire de la voie    None             19  non
# 8           gauche      même sens que la voie    None             10  non
# 9           gauche      même sens que la voie    None              9  non
#
#   coronapiste amenagement_temporaire infrastructure_bidirection  \
# 0         non                    non                        non
# 1         non                    non                        oui
# 2         non                    non                        non
# 3         non                    non                        non
# 4         non                    non                        non
# 5         non                    non                        non
# 6         non                    non                        non
# 7         non                    non                        oui
# 8         non                    non                        non
# 9         non                    non                        non
#
#   voie_a_sens_unique position_amenagement vitesse_maximale_autorisee  \
# 0                non      niveau chaussée                non définie
# 1                non             indéfini                non définie
# 2                oui      niveau chaussée                    30 km/h
# 3                oui             indéfini                    30 km/h
# 4                oui             indéfini                    30 km/h
# 5                oui             indéfini                    30 km/h
# 6                oui             indéfini                    30 km/h
# 7                non             indéfini                non définie
# 8                oui             indéfini                    30 km/h
# 9                oui      niveau chaussée                    30 km/h
#
#                  date_export  source  st_length_shape  \
# 0  2015-01-01T01:00:00+00:00  OSMIUM        43.423446
# 1  2015-01-01T01:00:00+00:00  OSMIUM       107.601872
# 2  2015-01-01T01:00:00+00:00  OSMIUM       114.152406
# 3  2015-01-01T01:00:00+00:00  OSMIUM        33.624047
# 4  2015-01-01T01:00:00+00:00  OSMIUM        65.956146
# 5  2015-01-01T01:00:00+00:00  OSMIUM        70.273358
# 6  2015-01-01T01:00:00+00:00  OSMIUM       164.660611
# 7  2015-01-01T01:00:00+00:00  OSMIUM        27.952889
# 8  2015-01-01T01:00:00+00:00  OSMIUM       156.600414
# 9  2015-01-01T01:00:00+00:00  OSMIUM       119.596718
#
#                                            geo_shape  \
# 0  {'type': 'Feature', 'geometry': {'coordinates'...
# 1  {'type': 'Feature', 'geometry': {'coordinates'...
# 2  {'type': 'Feature', 'geometry': {'coordinates'...
# 3  {'type': 'Feature', 'geometry': {'coordinates'...
# 4  {'type': 'Feature', 'geometry': {'coordinates'...
# 5  {'type': 'Feature', 'geometry': {'coordinates'...
# 6  {'type': 'Feature', 'geometry': {'coordinates'...
# 7  {'type': 'Feature', 'geometry': {'coordinates'...
# 8  {'type': 'Feature', 'geometry': {'coordinates'...
# 9  {'type': 'Feature', 'geometry': {'coordinates'...
#
#                                         geo_point_2d
# 0  {'lon': 2.376593350313773, 'lat': 48.824291931...
# 1  {'lon': 2.332733258534664, 'lat': 48.865138181...
# 2  {'lon': 2.3347381557799367, 'lat': 48.88731216...
# 3  {'lon': 2.3352581990982153, 'lat': 48.83193312...
# 4  {'lon': 2.377825209106115, 'lat': 48.851362217...
# 5  {'lon': 2.3226479722944178, 'lat': 48.89610506...
# 6  {'lon': 2.317424877498934, 'lat': 48.895042951...
# 7  {'lon': 2.38941724974755, 'lat': 48.8768999991...
# 8  {'lon': 2.373100390830526, 'lat': 48.872481513...
# 9  {'lon': 2.3396197617078474, 'lat': 48.87357629...

# %% [markdown]
# ### Retrieving the dataset as a .csv and converting it to a DataFrame

# %%
dataset_id = 'amenagements-cyclables'
export_url = f'https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/{dataset_id}/exports/csv'
params = {"select": "nom, amenagement, arrondissement, date_export, st_length_shape, geo_shape, geo_point_2d"}

# Downloading the csv of the full dataset and saving it locally
response = requests.get(export_url, params=params)
with open(f"{dataset_id}_Paris_Data.csv", "wb") as f:
    f.write(response.content)

# Converting the csv into a DataFrame with relevant columns
df = pd.read_csv(f"{dataset_id}_Paris_Data.csv", sep=";")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136926 entries, 0 to 136925
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   nom              123212 non-null  object
#  1   amenagement      136926 non-null  object
#  2   arrondissement   136926 non-null  int64
#  3   date_export      136926 non-null  object
#  4   st_length_shape  136926 non-null  float64
#  5   geo_shape        136926 non-null  object
#  6   geo_point_2d     136926 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 7.3+ MB

# %%
df.head()
# Out:
#                               nom                  amenagement  \
# 0                 Square du Rhône                voie piétonne
# 1                  Rue Jacquemont  double-sens cyclable simple
# 2  Rue Marguerite de Rochechouart               bande cyclable
# 3                     Rue Pradier  double-sens cyclable simple
# 4                    Rue du Delta  double-sens cyclable simple
#
#    arrondissement                date_export  st_length_shape  \
# 0              17  2021-01-01T01:00:00+00:00        59.578972
# 1              17  2021-01-01T01:00:00+00:00       167.174771
# 2               9  2021-01-01T01:00:00+00:00       164.533872
# 3              19  2021-01-01T01:00:00+00:00       173.307351
# 4               9  2021-01-01T01:00:00+00:00       216.079993
#
#                                            geo_shape  \
# 0  {"coordinates": [[2.3008191005798406, 48.88862...
# 1  {"coordinates": [[2.3236381004424285, 48.88862...
# 2  {"coordinates": [[2.345023099540479, 48.878346...
# 3  {"coordinates": [[2.3830538001976085, 48.87693...
# 4  {"coordinates": [[2.3496701995597253, 48.88239...
#
#                              geo_point_2d
# 0   48.88884600558725, 2.3005780283356656
# 1   48.88806434279106, 2.3228773233498208
# 2   48.87901301150777, 2.3455079416434037
# 3   48.87625877793356, 2.3824668939223757
# 4  48.882424006401074, 2.3481975812357345
