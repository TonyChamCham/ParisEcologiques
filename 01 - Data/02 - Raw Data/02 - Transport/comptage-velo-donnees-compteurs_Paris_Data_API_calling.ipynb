# %% [markdown]
# ## Listing of Paris' cycles traffic with the count, location and date (2024-2025).

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Connecting to Paris Data's API (and testing the response's status code)

# %%
params = {"select":"*"}
response = requests.get('https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/comptage-velo-donnees-compteurs/records?',params=params)
response.status_code
# Out:
# 200

# %%
pd.DataFrame(response.json()["results"])
# Out:
#            id_compteur                        nom_compteur         id  \
# 0  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 1  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 2  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 3  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 4  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 5  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 6  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 7  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 8  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
# 9  100003098-101003098  106 avenue Denfert Rochereau NE-SO  100003098
#
#                            name  sum_counts                       date  \
# 0  106 avenue Denfert Rochereau           0  2024-04-01T03:00:00+00:00
# 1  106 avenue Denfert Rochereau           0  2024-04-01T09:00:00+00:00
# 2  106 avenue Denfert Rochereau           0  2024-04-01T10:00:00+00:00
# 3  106 avenue Denfert Rochereau           0  2024-04-01T12:00:00+00:00
# 4  106 avenue Denfert Rochereau           0  2024-04-01T15:00:00+00:00
# 5  106 avenue Denfert Rochereau           0  2024-04-01T17:00:00+00:00
# 6  106 avenue Denfert Rochereau           0  2024-04-01T18:00:00+00:00
# 7  106 avenue Denfert Rochereau           0  2024-04-01T20:00:00+00:00
# 8  106 avenue Denfert Rochereau           0  2024-04-01T21:00:00+00:00
# 9  106 avenue Denfert Rochereau           0  2024-04-01T22:00:00+00:00
#
#   installation_date                                      url_photos_n1  \
# 0        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 1        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 2        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 3        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 4        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 5        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 6        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 7        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 8        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
# 9        2012-02-22  https://filer.eco-counter-tools.com/file/09/73...
#
#                          coordinates      counter  \
# 0  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 1  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 2  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 3  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 4  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 5  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 6  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 7  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 8  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
# 9  {'lon': 2.33305, 'lat': 48.83507}  Y2H20114504
#
#                                               photos  \
# 0  https://filer.eco-counter-tools.com/file/09/73...
# 1  https://filer.eco-counter-tools.com/file/09/73...
# 2  https://filer.eco-counter-tools.com/file/09/73...
# 3  https://filer.eco-counter-tools.com/file/09/73...
# 4  https://filer.eco-counter-tools.com/file/09/73...
# 5  https://filer.eco-counter-tools.com/file/09/73...
# 6  https://filer.eco-counter-tools.com/file/09/73...
# 7  https://filer.eco-counter-tools.com/file/09/73...
# 8  https://filer.eco-counter-tools.com/file/09/73...
# 9  https://filer.eco-counter-tools.com/file/09/73...
#
#           test_lien_vers_photos_du_site_de_comptage_ id_photo_1  \
# 0  https://filer.eco-counter-tools.com/file/09/73...     https:
# 1  https://filer.eco-counter-tools.com/file/09/73...     https:
# 2  https://filer.eco-counter-tools.com/file/09/73...     https:
# 3  https://filer.eco-counter-tools.com/file/09/73...     https:
# 4  https://filer.eco-counter-tools.com/file/09/73...     https:
# 5  https://filer.eco-counter-tools.com/file/09/73...     https:
# 6  https://filer.eco-counter-tools.com/file/09/73...     https:
# 7  https://filer.eco-counter-tools.com/file/09/73...     https:
# 8  https://filer.eco-counter-tools.com/file/09/73...     https:
# 9  https://filer.eco-counter-tools.com/file/09/73...     https:
#
#                                     url_sites type_dimage mois_annee_comptage
# 0  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 1  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 2  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 3  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 4  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 5  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 6  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 7  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 8  https://www.eco-visio.net/Photos/100003098         jpg             2024-04
# 9  https://www.eco-visio.net/Photos/100003098         jpg             2024-04

# %% [markdown]
# ### Retrieving the dataset as a .csv and converting it to a DataFrame

# %%
dataset_id = 'comptage-velo-donnees-compteurs'
export_url = f'https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/{dataset_id}/exports/csv'
params = {"select": "nom_compteur, id, sum_counts, date, installation_date, coordinates"}

# Downloading the csv of the full dataset and saving it locally
response = requests.get(export_url, params=params)
with open(f"{dataset_id}_Paris_Data.csv", "wb") as f:
    f.write(response.content)

# Converting the csv into a DataFrame
df = pd.read_csv(f"{dataset_id}_Paris_Data.csv", sep=";")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920645 entries, 0 to 920644
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   nom_compteur       920645 non-null  object
#  1   id                 885343 non-null  float64
#  2   sum_counts         920645 non-null  int64
#  3   date               920645 non-null  object
#  4   installation_date  885343 non-null  object
#  5   coordinates        885343 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 42.1+ MB

# %%
df.head()
# Out:
#                          nom_compteur           id  sum_counts  \
# 0  106 avenue Denfert Rochereau NE-SO  100003098.0           0
# 1  106 avenue Denfert Rochereau NE-SO  100003098.0           0
# 2  106 avenue Denfert Rochereau NE-SO  100003098.0           0
# 3  106 avenue Denfert Rochereau NE-SO  100003098.0           0
# 4  106 avenue Denfert Rochereau NE-SO  100003098.0           0
#
#                         date installation_date        coordinates
# 0  2024-04-01T03:00:00+00:00        2012-02-22  48.83507, 2.33305
# 1  2024-04-01T04:00:00+00:00        2012-02-22  48.83507, 2.33305
# 2  2024-04-01T05:00:00+00:00        2012-02-22  48.83507, 2.33305
# 3  2024-04-01T09:00:00+00:00        2012-02-22  48.83507, 2.33305
# 4  2024-04-01T06:00:00+00:00        2012-02-22  48.83507, 2.33305
