# %% [markdown]
# ## 2011, 2014, 2016 and 2022 Paris' traffic composition between 7am and 9pm

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Connecting to Paris Data's API (and testing the response's status code)

# %%
params = {"select":"annee, arrondissement, latitude, longitude, periode, heure, vehicules, nombre, secteur"}
response = requests.get('https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/compositions-du-trafic/records?',params=params)
response.status_code
# Out:
# 200

# %%
pd.DataFrame(response.json()["results"])
# Out:
#         annee arrondissement  latitude longitude  \
# 0  2016-01-01          75016  48.86365   2.26936
# 1  2016-01-01          75016  48.86365   2.26936
# 2  2016-01-01          75016  48.86365   2.26936
# 3  2016-01-01          75016  48.86365   2.26936
# 4  2016-01-01          75016  48.86365   2.26936
# 5  2016-01-01          75016  48.86365   2.26936
# 6  2016-01-01          75016  48.86365   2.26936
# 7  2016-01-01          75016  48.86365   2.26936
# 8  2016-01-01          75016  48.86365   2.26936
# 9  2016-01-01          75016  48.86365   2.26936
#
#                              periode    heure              vehicules  \
# 0  MOYENNE DU 15 AU 16 NOVEMBRE 2016  08h-09h   Deux roues-motorisés
# 1  MOYENNE DU 15 AU 16 NOVEMBRE 2016  12h-13h                    Bus
# 2  MOYENNE DU 15 AU 16 NOVEMBRE 2016  14h-15h                Vélib's
# 3  MOYENNE DU 15 AU 16 NOVEMBRE 2016  16h-17h                  Taxis
# 4  MOYENNE DU 15 AU 16 NOVEMBRE 2016  16h-17h                Vélib's
# 5  MOYENNE DU 15 AU 16 NOVEMBRE 2016  17h-18h                    Bus
# 6  MOYENNE DU 15 AU 16 NOVEMBRE 2016  17h-18h       Vélos Personnels
# 7  MOYENNE DU 15 AU 16 NOVEMBRE 2016  10h-11h           Poids lourds
# 8  MOYENNE DU 15 AU 16 NOVEMBRE 2016  11h-12h                  Taxis
# 9  MOYENNE DU 15 AU 16 NOVEMBRE 2016  13h-14h  Véhicules Utilitaires
#
#        nombre    secteur
# 0  136.000000  Maréchaux
# 1    5.000000  Maréchaux
# 2    2.666667  Maréchaux
# 3   30.000000  Maréchaux
# 4    2.666667  Maréchaux
# 5   11.000000  Maréchaux
# 6   10.666667  Maréchaux
# 7    3.666667  Maréchaux
# 8   21.000000  Maréchaux
# 9   76.000000  Maréchaux

# %% [markdown]
# ### Retrieving the dataset as a .csv and converting it to a DataFrame

# %%
dataset_id = 'compositions-du-trafic'
export_url = f'https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/{dataset_id}/exports/csv'
params = {"select": "annee, arrondissement, latitude, longitude, periode, heure, vehicules, nombre, secteur"}

# Downloading the csv of the full dataset
response = requests.get(export_url, params=params)
with open(f"{dataset_id}_Paris_Data.csv", "wb") as f:
    f.write(response.content)

# Converting the csv into a DataFrame
df = pd.read_csv(f"{dataset_id}_Paris_Data.csv", sep=";")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14199 entries, 0 to 14198
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   annee           14199 non-null  object
#  1   arrondissement  14199 non-null  object
#  2   latitude        14199 non-null  object
#  3   longitude       14199 non-null  float64
#  4   periode         14199 non-null  object
#  5   heure           14199 non-null  object
#  6   vehicules       14199 non-null  object
#  7   nombre          14199 non-null  float64
#  8   secteur         14199 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 998.5+ KB

# %%
df.head()
# Out:
#         annee arrondissement  latitude  longitude  \
# 0  2016-01-01          75016  48.86365    2.26936
# 1  2016-01-01          75016  48.86365    2.26936
# 2  2016-01-01          75016  48.86365    2.26936
# 3  2016-01-01          75016  48.86365    2.26936
# 4  2016-01-01          75016  48.86365    2.26936
#
#                              periode    heure             vehicules  \
# 0  MOYENNE DU 15 AU 16 NOVEMBRE 2016  08h-09h  Deux roues-motorisés
# 1  MOYENNE DU 15 AU 16 NOVEMBRE 2016  12h-13h                   Bus
# 2  MOYENNE DU 15 AU 16 NOVEMBRE 2016  14h-15h               Vélib's
# 3  MOYENNE DU 15 AU 16 NOVEMBRE 2016  16h-17h                 Taxis
# 4  MOYENNE DU 15 AU 16 NOVEMBRE 2016  16h-17h               Vélib's
#
#        nombre    secteur
# 0  136.000000  Maréchaux
# 1    5.000000  Maréchaux
# 2    2.666667  Maréchaux
# 3   30.000000  Maréchaux
# 4    2.666667  Maréchaux
