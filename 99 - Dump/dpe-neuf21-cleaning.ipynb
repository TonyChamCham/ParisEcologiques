# %% [markdown]
# Importing needed libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dpe_neuf = pd.read_csv("dpe-neuf21.csv")
dpe_neuf.describe()
# Out:
#        numero_rpls_logement  numero_immatriculation_copropriete  version_dpe  \
# count                   0.0                                 0.0  5906.000000
# mean                    NaN                                 NaN     2.118490
# std                     NaN                                 NaN     0.359037
# min                     NaN                                 NaN     1.000000
# 25%                     NaN                                 NaN     2.100000
# 50%                     NaN                                 NaN     2.200000
# 75%                     NaN                                 NaN     2.300000
# max                     NaN                                 NaN     2.400000
#
#        hauteur_sous_plafond  nombre_appartement  nombre_niveau_immeuble  \
# count           5906.000000         5867.000000             5440.000000
# mean               2.499577           62.649054                1.009191
# ...

# %%
nrj = dpe_neuf[["numero_dpe","date_derniere_modification_dpe","date_etablissement_dpe","categorie_enr","etiquette_dpe","etiquette_ges","emission_ges_5_usages","emission_ges_5_usages par_m2","emission_ges_chauffage","emission_ges_ecs","emission_ges_refroidissement","emission_ges_eclairage","emission_ges_auxiliaires","type_energie_n1","emission_ges_5_usages_energie_n1","emission_ges_chauffage_energie_n1","emission_ges_ecs_energie_n1","type_energie_n2","emission_ges_5_usages_energie_n2","emission_ges_chauffage_energie_n2","emission_ges_ecs_energie_n2","type_energie_principale_chauffage"]]
print(nrj.info())
nrj.head(25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   numero_dpe                         5906 non-null   object
#  1   date_derniere_modification_dpe     5906 non-null   object
#  2   date_etablissement_dpe             5906 non-null   object
#  3   categorie_enr                      3039 non-null   object
#  4   etiquette_dpe                      5906 non-null   object
#  5   etiquette_ges                      5906 non-null   object
#  6   emission_ges_5_usages              5906 non-null   float64
#  7   emission_ges_5_usages par_m2       5906 non-null   float64
#  8   emission_ges_chauffage             5906 non-null   float64
#  9   emission_ges_ecs                   5906 non-null   float64
#  10  emission_ges_refroidissement       5906 non-null   float64
# ...

# %%
nrj["date_derniere_modification_dpe"]=pd.to_datetime(nrj["date_derniere_modification_dpe"])
nrj["date_etablissement_dpe"]=pd.to_datetime(nrj["date_etablissement_dpe"])
nrj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   numero_dpe                         5906 non-null   object
#  1   date_derniere_modification_dpe     5906 non-null   datetime64[ns]
#  2   date_etablissement_dpe             5906 non-null   datetime64[ns]
#  3   categorie_enr                      3039 non-null   object
#  4   etiquette_dpe                      5906 non-null   object
#  5   etiquette_ges                      5906 non-null   object
#  6   emission_ges_5_usages              5906 non-null   float64
#  7   emission_ges_5_usages par_m2       5906 non-null   float64
#  8   emission_ges_chauffage             5906 non-null   float64
#  9   emission_ges_ecs                   5906 non-null   float64
#  10  emission_ges_refroidissement       5906 non-null   float64
# ...

# %%
nrj.to_csv("dpe-neuf21-cleaned.csv")
